# %% [markdown]
# # Python for Data Vizualization
# ## 1. Pandas

# %% [markdown]
# ### Load sample data

# %%
import pandas as pd
filename = 'data/runs_Jun29.xlsx'
df = pd.read_excel(filename)
df
# Out:
#              id                    name  type display_type  \
# 0    5547955414            Morning Ride  Ride         Ride
# 1    5547303663             Morning Run   Run          Run
# 2    5545814357              Night Ride  Ride         Ride
# 3    5542735353             Morning Run   Run          Run
# 4    5534194357          Afternoon Ride  Ride         Ride
# ..          ...                     ...   ...          ...
# 312  3245533219             Morning Run   Run          Run
# 313  3245509676            Morning Ride  Ride         Ride
# 314  3237835324             Morning run   Run          Run
# 315  3235266724               Lunch run   Run          Run
# 316  3234438437  The long way back home  Ride         Ride
#
#     activity_type_display_name  private    bike_id  athlete_gear_id  \
# 0                         Ride     True  7239918.0              NaN
# 1                          Run    False        NaN        6169885.0
# ...

# %% [markdown]
# ### Renaming and deleting columns

# %%
df.rename(columns={
    'start_day' : 'Start Day',
    'distance' : 'Distance in mi',
    'moving_time' : 'Moving Time',
    'elapsed_time' : 'Elapsed Time',
    'elevation_gain' : 'Elevation Gain',
    'calories' : 'Calories'
})
# Out:
#              ID  Type Activity Type                Start Time Start Day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      Distance in mi Moving Time Elapsed Time Elevation Gain    Calories
# ...

# %%
df[
    'calories'
].sum()
# Out:
# 90264.38780343533

# %%
df[
    'Type'
] == 'Run'
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 312     True
# 313    False
# 314     True
# 315     True
# 316    False
# Name: Type, Length: 317, dtype: bool

# %%
df
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
df['Type'].value_counts()
# Out:
# Run               185
# Ride              106
# Rowing              7
# Walk                5
# Swim                3
# Yoga                3
# Workout             3
# Hike                2
# WeightTraining      1
# Kayaking            1
# VirtualRide         1
# Name: Type, dtype: int64

# %%
run_filter = df['Type']=='Run'

# %%
run_filter.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Type, dtype: bool

# %%
ride_filter = df['Type'] == 'Ride'

# %%
ride_filter.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Type, dtype: bool

# %%
df[ride_filter].head()
# Out:
#             ID  Type Activity Type                Start Time start_day  \
# 0   5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 2   5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 4   5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# 7   5542735510  Ride          Ride  2021-06-24T18:21:29+0000       Thu
# 11  5480327610  Ride          Ride  2021-06-15T11:32:16+0000       Tue
#
#     distance moving_time elapsed_time elevation_gain    calories
# 0       3.32       15:17        15:20             20  114.254265
# 2       3.05       13:49        37:59              0   86.903236
# 4       4.30       15:30        15:30              0  111.812202
# 7       0.00       25:12        25:12              0  280.000000
# 11      0.00       13:34        13:34              0  111.000000

# %%
df[ride_filter].value_counts()
# Out:
# ID          Type  Activity Type  Start Time                start_day  distance  moving_time  elapsed_time  elevation_gain  calories
# 3504051367  Ride  Ride           2020-05-24T11:56:26+0000  Sun        22.78     1:59:21      2:00:11       370             567.223145    1
# 4691179815  Ride  Ride           2021-01-08T14:17:00+0000  Fri        3.52      21:45        30:59         84              128.000000    1
# 4903168886  Ride  Ride           2021-03-06T19:44:06+0000  Sat        31.15     2:48:09      3:51:28       493             695.843933    1
# 4880684555  Ride  Ride           2021-03-02T23:45:13+0000  Tue        0.00      43:31        43:31         0               543.000000    1
# 4873690897  Ride  Ride           2021-02-25T14:05:32+0000  Thu        20.93     1:40:45      1:49:27       444             463.278961    1
#                                                                                                                                         ..
# ...

# %%
df
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
df['start_day'].value_counts()
# Out:
# Thu    64
# Tue    63
# Mon    51
# Wed    44
# Sat    33
# Sun    31
# Fri    31
# Name: start_day, dtype: int64

# %%
df['start_day']=='Thu'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 312     True
# 313     True
# 314    False
# 315    False
# 316    False
# Name: start_day, Length: 317, dtype: bool

# %%
day_filter = df['start_day']=='Thu'

# %%
df[day_filter].tail()
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 301  3275165664   Run           Run  2020-04-09T12:32:36+0000       Thu
# 302  3275108392  Ride          Ride  2020-04-09T11:42:36+0000       Thu
# 311  3245608723  Ride          Ride  2020-04-02T11:24:06+0000       Thu
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
#
#      distance moving_time elapsed_time elevation_gain  calories
# 301      1.82       15:28        15:44              0       0.0
# 302      7.53       46:18        48:53            195       NaN
# 311      2.72       19:11        21:35             66       NaN
# 312      1.01        6:14         6:14              0       0.0
# 313      0.52        3:46         3:46              9       NaN

# %%
df
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
type(df[day_filter])
# Out:
# pandas.core.frame.DataFrame

# %%
df[day_filter]
# Out:
#              ID    Type Activity Type                Start Time start_day  \
# 6    5542735421  Rowing   Water Sport  2021-06-24T18:46:56+0000       Thu
# 7    5542735510    Ride          Ride  2021-06-24T18:21:29+0000       Thu
# 17   5445959640    Ride          Ride  2021-06-10T12:00:32+0000       Thu
# 22   5405841202  Rowing   Water Sport  2021-06-03T11:31:29+0000       Thu
# 29   5262951468    Ride          Ride  2021-05-06T19:33:25+0000       Thu
# ..          ...     ...           ...                       ...       ...
# 301  3275165664     Run           Run  2020-04-09T12:32:36+0000       Thu
# 302  3275108392    Ride          Ride  2020-04-09T11:42:36+0000       Thu
# 311  3245608723    Ride          Ride  2020-04-02T11:24:06+0000       Thu
# 312  3245533219     Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676    Ride          Ride  2020-04-02T11:09:56+0000       Thu
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
thursday = df[day_filter]

# %%
thursday['Type'][0:30]
# Out:
# 6      Rowing
# 7        Ride
# 17       Ride
# 22     Rowing
# 29       Ride
# 30        Run
# 33        Run
# 37        Run
# 42        Run
# 47        Run
# 48        Run
# 49        Run
# 50       Ride
# 51        Run
# 56        Run
# 62       Ride
# 63       Ride
# 72        Run
# 73        Run
# 74        Run
# 78        Run
# 79        Run
# 84        Run
# 91       Ride
# 92        Run
# 96        Run
# 102      Ride
# 103       Run
# 107       Run
# 117       Run
# Name: Type, dtype: object

# %%
df
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
thursday
# Out:
#              ID    Type Activity Type                Start Time start_day  \
# 6    5542735421  Rowing   Water Sport  2021-06-24T18:46:56+0000       Thu
# 7    5542735510    Ride          Ride  2021-06-24T18:21:29+0000       Thu
# 17   5445959640    Ride          Ride  2021-06-10T12:00:32+0000       Thu
# 22   5405841202  Rowing   Water Sport  2021-06-03T11:31:29+0000       Thu
# 29   5262951468    Ride          Ride  2021-05-06T19:33:25+0000       Thu
# ..          ...     ...           ...                       ...       ...
# 301  3275165664     Run           Run  2020-04-09T12:32:36+0000       Thu
# 302  3275108392    Ride          Ride  2020-04-09T11:42:36+0000       Thu
# 311  3245608723    Ride          Ride  2020-04-02T11:24:06+0000       Thu
# 312  3245533219     Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676    Ride          Ride  2020-04-02T11:09:56+0000       Thu
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
thursday.loc [: , ['Type']].tail()
# Out:
#      Type
# 301   Run
# 302  Ride
# 311  Ride
# 312   Run
# 313  Ride

# %%
thursday
# Out:
#              ID    Type Activity Type                Start Time start_day  \
# 6    5542735421  Rowing   Water Sport  2021-06-24T18:46:56+0000       Thu
# 7    5542735510    Ride          Ride  2021-06-24T18:21:29+0000       Thu
# 17   5445959640    Ride          Ride  2021-06-10T12:00:32+0000       Thu
# 22   5405841202  Rowing   Water Sport  2021-06-03T11:31:29+0000       Thu
# 29   5262951468    Ride          Ride  2021-05-06T19:33:25+0000       Thu
# ..          ...     ...           ...                       ...       ...
# 301  3275165664     Run           Run  2020-04-09T12:32:36+0000       Thu
# 302  3275108392    Ride          Ride  2020-04-09T11:42:36+0000       Thu
# 311  3245608723    Ride          Ride  2020-04-02T11:24:06+0000       Thu
# 312  3245533219     Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676    Ride          Ride  2020-04-02T11:09:56+0000       Thu
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %% [markdown]
# ## Escape M enters markdown cell

# %%
thursday['Type']=='Run'
# Out:
# 6      False
# 7      False
# 17     False
# 22     False
# 29     False
#        ...
# 301     True
# 302    False
# 311    False
# 312     True
# 313    False
# Name: Type, Length: 64, dtype: bool

# %%
thursday_runs = thursday['Type']=='Run'

# %%
thursday_runs.head()
# Out:
# 6     False
# 7     False
# 17    False
# 22    False
# 29    False
# Name: Type, dtype: bool

# %%
thursday['Type'].value_counts()
# Out:
# Run       43
# Ride      19
# Rowing     2
# Name: Type, dtype: int64

# %%
thursday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 6 to 313
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              64 non-null     int64
#  1   Type            64 non-null     object
#  2   Activity Type   64 non-null     object
#  3   Start Time      64 non-null     object
#  4   start_day       64 non-null     object
#  5   distance        64 non-null     float64
#  6   moving_time     64 non-null     object
#  7   elapsed_time    64 non-null     object
#  8   elevation_gain  64 non-null     object
#  9   calories        58 non-null     float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.6+ KB

# %%
thursday.rename(columns={
    'start_day' : 'Start Day',
    'distance' : 'Distance in mi',
    'moving_time' : 'Moving Time',
    'elapsed_time' : 'Elapsed Time',
    'elevation_gain' : 'Elevation Gain',
    'calories' : 'Calories'
})
# Out:
#              ID    Type Activity Type                Start Time Start Day  \
# 6    5542735421  Rowing   Water Sport  2021-06-24T18:46:56+0000       Thu
# 7    5542735510    Ride          Ride  2021-06-24T18:21:29+0000       Thu
# 17   5445959640    Ride          Ride  2021-06-10T12:00:32+0000       Thu
# 22   5405841202  Rowing   Water Sport  2021-06-03T11:31:29+0000       Thu
# 29   5262951468    Ride          Ride  2021-05-06T19:33:25+0000       Thu
# ..          ...     ...           ...                       ...       ...
# 301  3275165664     Run           Run  2020-04-09T12:32:36+0000       Thu
# 302  3275108392    Ride          Ride  2020-04-09T11:42:36+0000       Thu
# 311  3245608723    Ride          Ride  2020-04-02T11:24:06+0000       Thu
# 312  3245533219     Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676    Ride          Ride  2020-04-02T11:09:56+0000       Thu
#
#      Distance in mi Moving Time Elapsed Time Elevation Gain    Calories
# ...

# %%
thursday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 6 to 313
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              64 non-null     int64
#  1   Type            64 non-null     object
#  2   Activity Type   64 non-null     object
#  3   Start Time      64 non-null     object
#  4   start_day       64 non-null     object
#  5   distance        64 non-null     float64
#  6   moving_time     64 non-null     object
#  7   elapsed_time    64 non-null     object
#  8   elevation_gain  64 non-null     object
#  9   calories        58 non-null     float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.6+ KB

# %%
thursday.rename(columns={'start_day' : 'Start Day'})
# Out:
#              ID    Type Activity Type                Start Time Start Day  \
# 6    5542735421  Rowing   Water Sport  2021-06-24T18:46:56+0000       Thu
# 7    5542735510    Ride          Ride  2021-06-24T18:21:29+0000       Thu
# 17   5445959640    Ride          Ride  2021-06-10T12:00:32+0000       Thu
# 22   5405841202  Rowing   Water Sport  2021-06-03T11:31:29+0000       Thu
# 29   5262951468    Ride          Ride  2021-05-06T19:33:25+0000       Thu
# ..          ...     ...           ...                       ...       ...
# 301  3275165664     Run           Run  2020-04-09T12:32:36+0000       Thu
# 302  3275108392    Ride          Ride  2020-04-09T11:42:36+0000       Thu
# 311  3245608723    Ride          Ride  2020-04-02T11:24:06+0000       Thu
# 312  3245533219     Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676    Ride          Ride  2020-04-02T11:09:56+0000       Thu
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
thursday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 6 to 313
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              64 non-null     int64
#  1   Type            64 non-null     object
#  2   Activity Type   64 non-null     object
#  3   Start Time      64 non-null     object
#  4   start_day       64 non-null     object
#  5   distance        64 non-null     float64
#  6   moving_time     64 non-null     object
#  7   elapsed_time    64 non-null     object
#  8   elevation_gain  64 non-null     object
#  9   calories        58 non-null     float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.6+ KB

# %%
row_filter = thursday['Type'] == 'Rowing'
ride_filter = thursday['Type'] == 'Ride'
run_filter = thursday['Type'] == 'Run'

# %%
thursday[ride_filter].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 7 to 313
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              19 non-null     int64
#  1   Type            19 non-null     object
#  2   Activity Type   19 non-null     object
#  3   Start Time      19 non-null     object
#  4   start_day       19 non-null     object
#  5   distance        19 non-null     float64
#  6   moving_time     19 non-null     object
#  7   elapsed_time    19 non-null     object
#  8   elevation_gain  19 non-null     object
#  9   calories        13 non-null     float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.6+ KB

# %%
thursday = thursday.rename(columns={'start_day' : 'Start Day', 'distance' : 'Distance', 'moving_time' : 'Moving Time', 'elapsed_time' : 'Elapsed Time', 'elevation_gain' : 'Elevation Gain', 'calories' : 'Calories'})

# %%
thursday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 6 to 313
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              64 non-null     int64
#  1   Type            64 non-null     object
#  2   Activity Type   64 non-null     object
#  3   Start Time      64 non-null     object
#  4   Start Day       64 non-null     object
#  5   Distance        64 non-null     float64
#  6   Moving Time     64 non-null     object
#  7   Elapsed Time    64 non-null     object
#  8   Elevation Gain  64 non-null     object
#  9   Calories        58 non-null     float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.6+ KB

# %%
thursday['Calories'].quantile()
# Out:
# 251.08595275878906

# %%
df.info()

df = df.rename({'start_day' : 'Start Day', 'moving_time' : 'Moving Time', 'distance' : 'Distance', 'elapsed_time' : 'Elapsed Time', 'elevation_gain' : 'Elevation Gain', 'calories' : 'Calories'})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 24.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 27.2+ KB

# %%
df.rename(columns={
    'start_day' : 'Start Day',
    'distance' : 'Distance in mi',
    'moving_time' : 'Moving Time',
    'elapsed_time' : 'Elapsed Time',
    'elevation_gain' : 'Elevation Gain',
    'calories' : 'Calories'
})
# Out:
#              ID  Type Activity Type                Start Time Start Day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      Distance in mi Moving Time Elapsed Time Elevation Gain    Calories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 27.2+ KB

# %%
thursday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 6 to 313
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              64 non-null     int64
#  1   Type            64 non-null     object
#  2   Activity Type   64 non-null     object
#  3   Start Time      64 non-null     object
#  4   Start Day       64 non-null     object
#  5   Distance        64 non-null     float64
#  6   Moving Time     64 non-null     object
#  7   Elapsed Time    64 non-null     object
#  8   Elevation Gain  64 non-null     object
#  9   Calories        58 non-null     float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 27.2+ KB

# %%
calories_missing = df['calories'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 312    False
# 313     True
# 314    False
# 315    False
# 316     True
# Name: calories, Length: 317, dtype: bool

# %%
df['calories'][20:30]
# Out:
# 20    182.000000
# 21    928.000000
# 22     89.000000
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27    990.427368
# 28    385.000000
# 29    428.542908
# Name: calories, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 27.2+ KB

# %%
df[23:27]
# Out:
#             ID         Type Activity Type                Start Time start_day  \
# 23  5400160758  VirtualRide  Virtual Ride  2021-06-02T11:39:00+0000       Wed
# 24  5397527715       Rowing   Water Sport  2021-06-01T12:00:00+0000       Tue
# 25  5392191866     Kayaking   Water Sport  2021-05-31T13:30:00+0000       Mon
# 26  5392193035         Yoga       Workout  2021-05-30T21:00:00+0000       Sun
#
#     distance moving_time elapsed_time elevation_gain  calories
# 23      10.0       45:00        45:00              0       NaN
# 24       0.0       15:00        15:00              0       NaN
# 25       8.0     5:00:00      5:00:00              0       NaN
# 26       0.0       45:00        45:00              0       NaN

# %%
df[23:27].dropna(how = 'any')
# Out:
# Empty DataFrame
# Columns: [ID, Type, Activity Type, Start Time, start_day, distance, moving_time, elapsed_time, elevation_gain, calories]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 27.2+ KB

# %%
df['calories'][24].dropna(how = 'any')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-229-cc019cef0f00> in <module>
# ----> 1 df['calories'][24].dropna(how = 'any')
#
# AttributeError: 'numpy.float64' object has no attribute 'dropna'

# %%
df
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 35.3+ KB

# %%
df
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 313  3245509676  Ride          Ride  2020-04-02T11:09:56+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
# 316  3234438437  Ride          Ride  2020-03-30T11:58:44+0000       Mon
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
df.dropna()
# Out:
#              ID  Type Activity Type                Start Time start_day  \
# 0    5547955414  Ride          Ride  2021-06-29T13:43:30+0000       Tue
# 1    5547303663   Run           Run  2021-06-29T11:35:56+0000       Tue
# 2    5545814357  Ride          Ride  2021-06-29T02:49:57+0000       Mon
# 3    5542735353   Run           Run  2021-06-28T12:11:04+0000       Mon
# 4    5534194357  Ride          Ride  2021-06-26T20:26:49+0000       Sat
# ..          ...   ...           ...                       ...       ...
# 306  3257701893   Run           Run  2020-04-05T10:31:11+0000       Sun
# 309  3249591168   Run           Run  2020-04-03T12:39:36+0000       Fri
# 312  3245533219   Run           Run  2020-04-02T11:15:33+0000       Thu
# 314  3237835324   Run           Run  2020-03-31T11:43:20+0000       Tue
# 315  3235266724   Run           Run  2020-03-30T16:36:10+0000       Mon
#
#      distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              317 non-null    int64
#  1   Type            317 non-null    object
#  2   Activity Type   317 non-null    object
#  3   Start Time      317 non-null    object
#  4   start_day       317 non-null    object
#  5   distance        317 non-null    float64
#  6   moving_time     317 non-null    object
#  7   elapsed_time    317 non-null    object
#  8   elevation_gain  317 non-null    object
#  9   calories        269 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 35.3+ KB

# %%
df['calories'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 312    False
# 313     True
# 314    False
# 315    False
# 316     True
# Name: calories, Length: 317, dtype: bool

# %%
calories_missing.value_counts()
# Out:
# False    269
# True      48
# Name: calories, dtype: int64

# %%
df[20:30]
# Out:
#             ID         Type Activity Type                Start Time start_day  \
# 20  5445959108         Ride          Ride  2021-06-08T23:03:38+0000       Tue
# 21  5420581290         Ride          Ride  2021-06-05T15:37:51+0000       Sat
# 22  5405841202       Rowing   Water Sport  2021-06-03T11:31:29+0000       Thu
# 23  5400160758  VirtualRide  Virtual Ride  2021-06-02T11:39:00+0000       Wed
# 24  5397527715       Rowing   Water Sport  2021-06-01T12:00:00+0000       Tue
# 25  5392191866     Kayaking   Water Sport  2021-05-31T13:30:00+0000       Mon
# 26  5392193035         Yoga       Workout  2021-05-30T21:00:00+0000       Sun
# 27  5376973048          Run           Run  2021-05-29T12:10:53+0000       Sat
# 28  5289249588          Run           Run  2021-05-12T21:01:55+0000       Wed
# 29  5262951468         Ride          Ride  2021-05-06T19:33:25+0000       Thu
#
#     distance moving_time elapsed_time elevation_gain    calories
# ...

# %%
df['Type'] == 'Run'
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 312     True
# 313    False
# 314     True
# 315     True
# 316    False
# Name: Type, Length: 317, dtype: bool

# %%
calories_missing
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 312    False
# 313     True
# 314    False
# 315    False
# 316     True
# Name: calories, Length: 317, dtype: bool

# %%
df
# Out:
# 20    182.000000
# 21    928.000000
# 22     89.000000
# 23      0.000000
# 24      0.000000
# 25      0.000000
# 26      0.000000
# 27    990.427368
# 28    385.000000
# 29    428.542908
# Name: calories, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-308-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'
