# %% [markdown]
# # 1) Pie Chart

# %%
import math
import matplotlib.pyplot as plt

num_activities = [29, 16, 27, 42, 35, 67, 
                  52, 46, 76, 64, 38, 13]

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
         'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# explode the most active month 
exp = [0, 0, 0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0]
cl = ['Lime', 'Violet', 'Teal', 'Tan']
plt.pie(num_activities, labels = months, explode = exp, colors = cl, autopct= '%2.1f%%')
plt.show()

# %% [markdown]
# # 1a) Pie Chart Optimized

# %%
avg_acts_pm = sum(num_activities) / 12
sum_acts_yr = sum(num_activities)
print(avg_acts_pm, sum_acts_yr)



peak_activ = [42, 67, 52, 46, 76, 64]
peak_month = ['Apr', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct']
exp = [0, 0, 0, 0, 0.2, 0]
cl = ['Orange', 'Red', 'Blue', 'Green', 'Purple', 'Yellow']
plt.pie(peak_activ, labels = peak_month, explode = exp, colors = cl, autopct= '%2.1f%%', shadow=True, radius=1.5, rotatelabels=True)
plt.show()
# Out:
# 42.083333333333336 505
