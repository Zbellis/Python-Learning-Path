# %%
filename = 'data/Runs and Rides.xlsx'
df = pd.read_excel(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d8ad37496394> in <module>
#       1 filename = 'data/Runs and Rides.xlsx'
# ----> 2 df = pd.read_excel(filename)
#
# NameError: name 'pd' is not defined

# %%
df

# %%
import pandas as pd

# %%
filename = 'data/Runs and Rides.xlsx'
df = pd.read_excel(filename)

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#      suffer_score     calories
# 0             NaN  4790.407227
# ...

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#      suffer_score     calories
# 0             NaN  4790.407227
# ...

# %%
filename = 'data/Runs and Rides.xlsx'
df = pd.read_excel(filename)
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#      suffer_score     calories
# 0             NaN  4790.407227
# ...

# %%
filename = 'data/Runs and Rides.xlsx'
df = pd.read_excel(filename)

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#      suffer_score     calories
# 0             NaN  4790.407227
# ...

# %%
filename = 'data/Runs and Rides.xlsx'
df = pd.read_excel(filename)

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...

# %%
df.head(20)
# Out:
#    type       start_date  distance          moving_time  elevation_gain  \
# 0   Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1   Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2   Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3   Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4   Run  Tue, 10/27/2020      0.28             01:47:00               0
# 5   Run  Tue, 10/27/2020      1.07             08:02:00              22
# 6   Run  Tue, 10/27/2020      1.01             07:11:00              13
# 7   Run  Mon, 10/26/2020      1.11             11:07:00              25
# 8   Run  Sun, 10/25/2020      1.17             14:15:00               0
# 9   Run  Fri, 10/23/2020      1.75             20:00:00               0
# 10  Run  Thu, 10/22/2020      2.50  1900-01-01 01:00:00               0
# 11  Run  Mon, 10/19/2020      0.75             07:41:00              22
# ...

# %%
df.dtypes
# Out:
# type               object
# start_date         object
# distance          float64
# moving_time        object
# elevation_gain      int64
# calories          float64
# dtype: object

# %%
df.shape
# Out:
# (182, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         calories
# 0    4790.407227
# 1     339.854095
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   type            182 non-null    object
#  1   start_date      182 non-null    object
#  2   distance        182 non-null    float64
#  3   moving_time     182 non-null    object
#  4   elevation_gain  182 non-null    int64
#  5   calories        182 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 8.7+ KB

# %%
df[['type']].head()
# Out:
#   type
# 0  Run
# 1  Run
# 2  Run
# 3  Run
# 4  Run

# %%
df[['calories', 'distance']].head(5)
# Out:
#       calories  distance
# 0  4790.407227     31.08
# 1   339.854095      2.20
# 2   170.246307      1.10
# 3   182.578537      1.18
# 4    43.724308      0.28

# %%
df['calories'][3:11]
# Out:
# 3     182.578537
# 4      43.724308
# 5     165.662521
# 6     156.122849
# 7     171.761826
# 8     180.319885
# 9     268.402252
# 10    383.432831
# Name: calories, dtype: float64

# %%
df.loc[:,'calories'].head()
# Out:
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# 4      43.724308
# Name: calories, dtype: float64

# %%
df.loc[[:,'calories']].head()
# Out:
#   File "<ipython-input-23-a319f4ac5ed7>", line 1
#     df.loc[[:,'calories']].head()
#             ^
# SyntaxError: invalid syntax

# %%
df.loc[:,['calories']].head()
# Out:
#       calories
# 0  4790.407227
# 1   339.854095
# 2   170.246307
# 3   182.578537
# 4    43.724308

# %%
df['type'].value_counts()
# Out:
# Run    182
# Name: type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   type            182 non-null    object
#  1   start_date      182 non-null    object
#  2   distance        182 non-null    float64
#  3   moving_time     182 non-null    object
#  4   elevation_gain  182 non-null    int64
#  5   calories        182 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 8.7+ KB

# %%
df['distance'].value_counts()
# Out:
# 1.00     8
# 1.01     6
# 0.75     4
# 2.26     4
# 0.71     3
#         ..
# 1.45     1
# 1.32     1
# 4.78     1
# 13.17    1
# 0.88     1
# Name: distance, Length: 129, dtype: int64

# %%
df['distance'].value_counts() > 5
# Out:
# 1.00      True
# 1.01      True
# 0.75     False
# 2.26     False
# 0.71     False
#          ...
# 1.45     False
# 1.32     False
# 4.78     False
# 13.17    False
# 0.88     False
# Name: distance, Length: 129, dtype: bool

# %%
df['distance'].value_counts.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-4b000439e1e2> in <module>
# ----> 1 df['distance'].value_counts.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %%
df.head()
# Out:
#   type       start_date  distance moving_time  elevation_gain     calories
# 0  Run   Wed, 12/9/2020     31.08    06:37:50             594  4790.407227
# 1  Run   Thu, 11/5/2020      2.20    21:53:00              45   339.854095
# 2  Run   Wed, 11/4/2020      1.10    11:17:00              25   170.246307
# 3  Run  Wed, 10/28/2020      1.18    09:02:00              25   182.578537
# 4  Run  Tue, 10/27/2020      0.28    01:47:00               0    43.724308

# %%
df['distance'].head()
# Out:
# 0    31.08
# 1     2.20
# 2     1.10
# 3     1.18
# 4     0.28
# Name: distance, dtype: float64

# %%
df['distance'].value_counts()
# Out:
# 1.00     8
# 1.01     6
# 0.75     4
# 2.26     4
# 0.71     3
#         ..
# 1.45     1
# 1.32     1
# 4.78     1
# 13.17    1
# 0.88     1
# Name: distance, Length: 129, dtype: int64

# %%
df.loc[distance]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e6677cd5a1d2> in <module>
# ----> 1 df.loc[distance]
#
# NameError: name 'distance' is not defined

# %%
df.loc[distance:,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-20505e30d2f4> in <module>
# ----> 1 df.loc[distance:,]
#
# NameError: name 'distance' is not defined

# %%
halfy_filter = df['distance'] >= 13

# %%
halfy_filter.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-07e0a04e14ca> in <module>
# ----> 1 halfy_filter.head()
#
# NameError: name 'halfy_filter' is not defined

# %%
halfy_filter = df['distance'] >= 13
print(halfy_filter)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# Name: distance, Length: 182, dtype: bool

# %%
halfy_filter.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: distance, dtype: bool

# %%
halfy_filter.tail()
# Out:
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# Name: distance, dtype: bool

# %%
df[halfy_filter].head()
# Out:
#     type       start_date  distance moving_time  elevation_gain     calories
# 0    Run   Wed, 12/9/2020     31.08    06:37:50             594  4790.407227
# 12   Run  Sat, 10/17/2020     19.40    03:01:38             317  2987.605469
# 84   Run   Fri, 5/29/2020     13.17    02:09:59             301  2028.363403
# 136  Run   Sun, 9/27/2020     13.10    01:53:41             352  2020.057373
# 165  Run   Sun, 10/6/2019     14.30    02:17:36             234     0.000000

# %%
df.loc[halfy_filter, :]
# Out:
#     type       start_date  distance moving_time  elevation_gain     calories
# 0    Run   Wed, 12/9/2020     31.08    06:37:50             594  4790.407227
# 12   Run  Sat, 10/17/2020     19.40    03:01:38             317  2987.605469
# 84   Run   Fri, 5/29/2020     13.17    02:09:59             301  2028.363403
# 136  Run   Sun, 9/27/2020     13.10    01:53:41             352  2020.057373
# 165  Run   Sun, 10/6/2019     14.30    02:17:36             234     0.000000

# %%
time_filter = df['moving_time'] >= '02:00:00'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-68020d3a545c> in <module>
# ----> 1 time_filter = df['moving_time'] >= '02:00:00'
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arraylike.py in __ge__(self, other)
#      47     @unpack_zerodim_and_defer("__ge__")
#      48     def __ge__(self, other):
# ---> 49         return self._cmp_method(other, operator.ge)
#      50
#      51     # -------------------------------------------------------------
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
# ...

# %%
time_filter = df['moving_time'] > '02:00:00'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-893bcb13e218> in <module>
# ----> 1 time_filter = df['moving_time'] > '02:00:00'
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      43     @unpack_zerodim_and_defer("__gt__")
#      44     def __gt__(self, other):
# ---> 45         return self._cmp_method(other, operator.gt)
#      46
#      47     @unpack_zerodim_and_defer("__ge__")
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
# ...

# %%
df = df.rename(columns={'type':'Type', 'calories': 'Calories'})

# %%
df
# Out:
#     Type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         Calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...

# %%
df['calories'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'calories'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-287056d2cb5e> in <module>
# ...

# %%
df['Calories'].sum()
# Out:
# 62238.02576577656

# %%
cal_burned = Int(df['Calories'].sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-2fc0e62d27db> in <module>
# ----> 1 cal_burned = Int(df['Calories'].sum())
#
# NameError: name 'Int' is not defined

# %%
df
# Out:
#     Type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         Calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            182 non-null    object
#  1   start_date      182 non-null    object
#  2   distance        182 non-null    float64
#  3   moving_time     182 non-null    object
#  4   elevation_gain  182 non-null    int64
#  5   Calories        182 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 8.7+ KB

# %%
df.to_excel(excel_writer='data/table_i702t60.xlsx', index=False)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
filename = 'data/Runs and Rides.xlsx'
df = pd.read_excel(filename)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b2070e8bbfaa> in <module>
#       1 filename = 'data/Runs and Rides.xlsx'
# ----> 2 df = pd.read_excel(filename)
#       3 df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
filename = 'data/Runs and Rides.xlsx'
df = pd.read_excel(filename)

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...

# %% [markdown]
# ## Creating Data
# My runs on strava 23-weeks away from Marathon

# %%
# Approach 1 List

runStats = [
    
    # if start time is before 12 am ... 'name = Morning Run : Afternoon, Evening'
    
    [132, 'Morning Run', 'Wed, 9/18/2019', 199, '46:33', '1:00:00', 800, 2989],
    [133, 'Morning Run', 'Wed, 9/18/2019', 199, '46:33', '1:00:00', 800, 2989],
    [134, 'Morning Run', 'Wed, 9/18/2019', 199, '46:33', '1:00:00', 800, 2989],
    [135, 'Morning Run', 'Wed, 9/18/2019', 199, '46:33', '1:00:00', 800, 2989],
    [136, 'Morning Run', 'Wed, 9/18/2019', 199, '46:33', '1:00:00', 800, 2989]
    
]

colNames = ['id',
           'name',
           'start_date',
           'start_time',
           'distance',
           'moving_time',
           'elapsed_time',
           'elevation',
           'calories']

# %%
df = pd.DataFrame(data = runStats, columns = colNames)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     567     try:
# --> 568         columns = _validate_or_indexify_columns(content, columns)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\construction.py in _validate_or_indexify_columns(content, columns)
#     691             # caller's responsibility to check for this...
# --> 692             raise AssertionError(
#     693                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 9 columns passed, passed data had 8 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...

# %%
df['start_date']
# Out:
# 0       Wed, 12/9/2020
# 1       Thu, 11/5/2020
# 2       Wed, 11/4/2020
# 3      Wed, 10/28/2020
# 4      Tue, 10/27/2020
#             ...
# 177      Thu, 5/7/2020
# 178     Tue, 4/28/2020
# 179     Fri, 4/24/2020
# 180     Wed, 4/22/2020
# 181     Mon, 4/20/2020
# Name: start_date, Length: 182, dtype: object

# %%
df[:, 'start_date']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-6a01044c641b> in <module>
# ----> 1 df[:, 'start_date']
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#    3082                 raise KeyError(key) from err
#
# ...

# %%
df['start_date'].head(20)
# Out:
# 0      Wed, 12/9/2020
# 1      Thu, 11/5/2020
# 2      Wed, 11/4/2020
# 3     Wed, 10/28/2020
# 4     Tue, 10/27/2020
# 5     Tue, 10/27/2020
# 6     Tue, 10/27/2020
# 7     Mon, 10/26/2020
# 8     Sun, 10/25/2020
# 9     Fri, 10/23/2020
# 10    Thu, 10/22/2020
# 11    Mon, 10/19/2020
# 12    Sat, 10/17/2020
# 13    Fri, 10/16/2020
# 14    Thu, 10/15/2020
# 15    Wed, 10/14/2020
# 16    Tue, 10/13/2020
# 17     Thu, 10/8/2020
# 18     Tue, 10/6/2020
# 19     Mon, 10/5/2020
# Name: start_date, dtype: object

# %%
df[:,'start_date']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c3ab2fc795ad> in <module>
# ----> 1 df[:,'start_date']
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#    3082                 raise KeyError(key) from err
#
# ...

# %%
df.loc[:, ['start_date']]
# Out:
#           start_date
# 0     Wed, 12/9/2020
# 1     Thu, 11/5/2020
# 2     Wed, 11/4/2020
# 3    Wed, 10/28/2020
# 4    Tue, 10/27/2020
# ..               ...
# 177    Thu, 5/7/2020
# 178   Tue, 4/28/2020
# 179   Fri, 4/24/2020
# 180   Wed, 4/22/2020
# 181   Mon, 4/20/2020
#
# [182 rows x 1 columns]

# %%
df.loc[0:50, ['start_date']]
# Out:
#          start_date
# 0    Wed, 12/9/2020
# 1    Thu, 11/5/2020
# 2    Wed, 11/4/2020
# 3   Wed, 10/28/2020
# 4   Tue, 10/27/2020
# 5   Tue, 10/27/2020
# 6   Tue, 10/27/2020
# 7   Mon, 10/26/2020
# 8   Sun, 10/25/2020
# 9   Fri, 10/23/2020
# 10  Thu, 10/22/2020
# 11  Mon, 10/19/2020
# 12  Sat, 10/17/2020
# 13  Fri, 10/16/2020
# 14  Thu, 10/15/2020
# 15  Wed, 10/14/2020
# 16  Tue, 10/13/2020
# 17   Thu, 10/8/2020
# 18   Tue, 10/6/2020
# 19   Mon, 10/5/2020
# 20    Fri, 9/4/2020
# 21    Wed, 9/2/2020
# 22    Tue, 9/1/2020
# 23   Mon, 8/31/2020
# 24   Sun, 8/30/2020
# 25   Thu, 8/27/2020
# 26   Mon, 8/24/2020
# 27   Sun, 8/23/2020
# 28   Fri, 8/21/2020
# 29   Wed, 8/19/2020
# 30   Tue, 8/18/2020
# 31   Mon, 8/17/2020
# 32    Thu, 8/6/2020
# 33    Mon, 8/3/2020
# 34    Sat, 8/1/2020
# 35   Fri, 7/31/2020
# 36   Thu, 7/30/2020
# 37   Wed, 7/29/2020
# 38   Tue, 7/28/2020
# 39   Mon, 7/27/2020
# 40    Sun, 3/8/2020
# 41    Fri, 3/5/2021
# 42    Thu, 3/4/2021
# 43    Tue, 3/2/2021
# ...

# %%
df.loc[50:100, ['start_date']]
# Out:
#          start_date
# 50    Tue, 2/9/2021
# 51    Sun, 2/7/2021
# 52    Sat, 2/6/2021
# 53    Thu, 2/4/2021
# 54    Thu, 2/4/2021
# 55    Thu, 2/4/2021
# 56    Tue, 2/2/2021
# 57    Tue, 2/2/2021
# 58    Mon, 2/1/2021
# 59   Thu, 1/28/2021
# 60   Thu, 1/28/2021
# 61   Sat, 5/29/2021
# 62   Wed, 5/12/2021
# 63    Thu, 5/6/2021
# 64   Tue, 4/27/2021
# 65   Sat, 4/24/2021
# 66   Thu, 4/22/2021
# 67   Tue, 4/20/2021
# 68   Mon, 4/19/2021
# 69   Thu, 4/15/2021
# 70   Tue, 4/13/2021
# 71    Tue, 4/6/2021
# 72   Thu, 3/18/2021
# 73   Tue, 3/16/2021
# 74   Tue, 3/16/2021
# 75   Sun, 3/14/2021
# 76   Sat, 3/13/2021
# 77   Thu, 3/11/2021
# 78   Thu, 3/11/2021
# 79   Thu, 3/11/2021
# 80   Thu, 3/11/2021
# 81    Thu, 6/4/2020
# 82    Wed, 6/3/2020
# 83    Mon, 6/1/2020
# 84   Fri, 5/29/2020
# 85   Thu, 5/28/2020
# 86   Thu, 5/28/2020
# 87   Wed, 5/27/2020
# 88   Tue, 5/26/2020
# 89   Thu, 5/21/2020
# 90   Mon, 7/27/2020
# 91   Sun, 7/26/2020
# 92   Sat, 7/25/2020
# 93   Thu, 7/16/2020
# ...

# %%
df.loc[100:150, ['start_date']]
# Out:
#           start_date
# 100   Wed, 6/17/2020
# 101   Tue, 6/16/2020
# 102   Sun, 6/14/2020
# 103   Sat, 6/13/2020
# 104   Fri, 6/12/2020
# 105   Thu, 6/11/2020
# 106   Wed, 6/10/2020
# 107   Wed, 6/10/2020
# 108    Tue, 6/9/2020
# 109    Tue, 6/9/2020
# 110   Wed, 1/27/2021
# 111   Tue, 1/26/2021
# 112   Tue, 1/26/2021
# 113   Mon, 1/25/2021
# 114   Thu, 1/21/2021
# 115   Wed, 1/20/2021
# 116   Wed, 1/20/2021
# 117   Tue, 1/19/2021
# 118   Mon, 1/18/2021
# 119   Fri, 1/15/2021
# 120   Thu, 1/14/2021
# 121   Wed, 1/13/2021
# 122    Fri, 1/8/2021
# 123    Thu, 1/7/2021
# 124    Wed, 1/6/2021
# 125    Tue, 1/5/2021
# 126    Mon, 1/4/2021
# 127    Sun, 1/3/2021
# 128    Sat, 1/2/2021
# 129  Wed, 12/30/2020
# 130   Sun, 10/4/2020
# 131   Sat, 10/3/2020
# 132   Fri, 10/2/2020
# 133   Thu, 10/1/2020
# 134   Tue, 9/29/2020
# 135   Mon, 9/28/2020
# 136   Sun, 9/27/2020
# 137   Fri, 9/25/2020
# 138   Thu, 9/24/2020
# 139   Thu, 9/24/2020
# 140   Wed, 9/23/2020
# 141   Tue, 9/22/2020
# ...

# %%
df.loc[150:, ['start_date']]
# Out:
#           start_date
# 150   Tue, 9/10/2019
# 151   Mon, 8/26/2019
# 152    Thu, 4/9/2020
# 153    Tue, 4/7/2020
# 154    Sun, 4/5/2020
# 155    Fri, 4/3/2020
# 156    Thu, 4/2/2020
# 157   Tue, 3/31/2020
# 158   Mon, 3/30/2020
# 159   Mon, 3/30/2020
# 160  Sun, 11/10/2019
# 161  Thu, 10/24/2019
# 162  Wed, 10/23/2019
# 163  Sun, 10/20/2019
# 164  Fri, 10/11/2019
# 165   Sun, 10/6/2019
# 166   Thu, 10/3/2019
# 167   Tue, 9/24/2019
# 168   Sun, 9/22/2019
# 169   Wed, 9/18/2019
# 170   Thu, 9/12/2019
# 171   Tue, 5/19/2020
# 172   Mon, 5/18/2020
# 173   Thu, 5/14/2020
# 174   Tue, 5/12/2020
# 175   Mon, 5/11/2020
# 176   Sun, 5/10/2020
# 177    Thu, 5/7/2020
# 178   Tue, 4/28/2020
# 179   Fri, 4/24/2020
# 180   Wed, 4/22/2020
# 181   Mon, 4/20/2020

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...

# %%
print(filename)
# Out:
# data/Runs and Rides.xlsx

# %%
filename = 'data/running_data.xlsx'

# %%
df
# Out:
#     type       start_date  distance          moving_time  elevation_gain  \
# 0    Run   Wed, 12/9/2020     31.08             06:37:50             594
# 1    Run   Thu, 11/5/2020      2.20             21:53:00              45
# 2    Run   Wed, 11/4/2020      1.10             11:17:00              25
# 3    Run  Wed, 10/28/2020      1.18             09:02:00              25
# 4    Run  Tue, 10/27/2020      0.28             01:47:00               0
# ..   ...              ...       ...                  ...             ...
# 177  Run    Thu, 5/7/2020      4.02  1900-01-01 05:51:00             125
# 178  Run   Tue, 4/28/2020      1.15             06:55:00               0
# 179  Run   Fri, 4/24/2020      0.52             04:24:00               0
# 180  Run   Wed, 4/22/2020      1.95             19:27:00              50
# 181  Run   Mon, 4/20/2020      2.17             15:00:00               0
#
#         calories
# 0    4790.407227
# 1     339.854095
# 2     170.246307
# 3     182.578537
# ...
